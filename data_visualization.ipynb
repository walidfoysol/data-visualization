# %% [markdown]
# <a href="https://colab.research.google.com/github/walidfoysol/data-visualization/blob/main/data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
data = pd.read_csv("/content/gdrive/MyDrive/Artificial Intelligence/heart_failure_clinical_records_dataset.csv")

# %%
data
# Out:
#       age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0    75.0        0                       582  ...        0     4            1
# 1    55.0        0                      7861  ...        0     6            1
# 2    65.0        0                       146  ...        1     7            1
# 3    50.0        1                       111  ...        0     7            1
# 4    65.0        1                       160  ...        0     8            1
# ..    ...      ...                       ...  ...      ...   ...          ...
# 294  62.0        0                        61  ...        1   270            0
# 295  55.0        0                      1820  ...        0   271            0
# 296  45.0        0                      2060  ...        0   278            0
# 297  45.0        0                      2413  ...        1   280            0
# 298  50.0        0                       196  ...        1   285            0
#
# [299 rows x 13 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sb

plt.figure(figsize=(10,8))
sb.countplot(data['age'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sb.countplot(data['anaemia'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sb.countplot(data['high_blood_pressure'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(14,10))
cor = data.corr()
sb.heatmap(cor,annot=True)
plt.show()
